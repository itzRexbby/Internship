# %% [markdown]
# #### Zomato Restaurant
# ##### Project Description
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#
# • Country code
#
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('zomatodf.csv',encoding='ISO-8859-1')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
# Out:
# Rows : 9551
# Columns : 21

# %%
d1=pd.read_excel('Country-Code.xlsx')

# %%
d1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df = pd.merge(df,d1, on='Country Code', how='left')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df = df.rename(columns={'Country': 'Country Name'})

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # Statistical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe().T
# Out:
#                        count          mean           std         min  \
# Restaurant ID         9551.0  9.051128e+06  8.791521e+06   53.000000
# Country Code          9551.0  1.836562e+01  5.675055e+01    1.000000
# Longitude             9551.0  6.412657e+01  4.146706e+01 -157.948486
# Latitude              9551.0  2.585438e+01  1.100794e+01  -41.330428
# Average Cost for two  9551.0  1.199211e+03  1.612118e+04    0.000000
# Price range           9551.0  1.804837e+00  9.056088e-01    1.000000
# Aggregate rating      9551.0  2.666370e+00  1.516378e+00    0.000000
# Votes                 9551.0  1.569097e+02  4.301691e+02    0.000000
#
#                                 25%           50%           75%           max
# Restaurant ID         301962.500000  6.004089e+06  1.835229e+07  1.850065e+07
# Country Code               1.000000  1.000000e+00  1.000000e+00  2.160000e+02
# Longitude                 77.081343  7.719196e+01  7.728201e+01  1.748321e+02
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country Name            0
# dtype: int64

# %%
missingvalues=df.isnull().sum().sort_values(ascending=False)
percentage=(missingvalues/len(df))*100
print(pd.concat([missingvalues,percentage],axis=1,keys=['Missing Values','% of missing values']))
# Out:
#                       Missing Values  % of missing values
# Cuisines                           9             0.094231
# Restaurant ID                      0             0.000000
# Country Code                       0             0.000000
# City                               0             0.000000
# Address                            0             0.000000
# Restaurant Name                    0             0.000000
# Locality                           0             0.000000
# Locality Verbose                   0             0.000000
# Longitude                          0             0.000000
# Latitude                           0             0.000000
# Average Cost for two               0             0.000000
# Currency                           0             0.000000
# Has Table booking                  0             0.000000
# Has Online delivery                0             0.000000
# Is delivering now                  0             0.000000
# ...

# %% [markdown]
# #### Cuisines having 9 null values lets remove them !|

# %%
df = df.dropna(subset=['Cuisines'])

# %%
missingvalues=df.isnull().sum().sort_values(ascending=False)
percentage=(missingvalues/len(df))*100
print(pd.concat([missingvalues,percentage],axis=1,keys=['Missing Values','% of missing values']))
# Out:
#                       Missing Values  % of missing values
# Restaurant ID                      0                  0.0
# Restaurant Name                    0                  0.0
# Country Code                       0                  0.0
# City                               0                  0.0
# Address                            0                  0.0
# Locality                           0                  0.0
# Locality Verbose                   0                  0.0
# Longitude                          0                  0.0
# Latitude                           0                  0.0
# Cuisines                           0                  0.0
# Average Cost for two               0                  0.0
# Currency                           0                  0.0
# Has Table booking                  0                  0.0
# Has Online delivery                0                  0.0
# Is delivering now                  0                  0.0
# ...

# %% [markdown]
# #### Now there is no null value present in our dataframe !

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
##### Lets drop some useless columns.
df=df.drop(['Latitude','Longitude'],axis=1)

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(18,15))
sns.countplot(x=df['Country Name'])
# Out:
# <Axes: xlabel='Country Name', ylabel='count'>

# %%
df['Country Name'].value_counts()
# Out:
# Country Name
# India             8652
# United States      425
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %% [markdown]
# #### Maximum no. of Restaurants are in India count of 8652  and Canada having minimum count of 4.

# %%
plt.figure(figsize=(18,15))
sns.countplot(x=df['Price range'])
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
Category=['Restaurant Name','City','Address','Locality','Locality Verbose','Cuisines','Currency','Has Table booking','Is delivering now','Rating color','Rating text','Country Name']
Numerical=['Restaurant ID','Country Code','Average Cost for two','Price range','Aggregate rating','Votes']

# %%
counts=df['Price range'].value_counts()
plt.pie(counts,labels=counts.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ##### Price range -
# - 1 = 46.5%
# - 2 = 32.6%
# - 3 = 14.7%
# - 4 = 6.1%

# %%
sns.countplot(x=df['Has Table booking'],hue=df['Price range'])
# Out:
# <Axes: xlabel='Has Table booking', ylabel='count'>

# %% [markdown]
# ##### As we can see price range 1 have no tables for booking.

# %%
counts=df['Has Online delivery'].value_counts()
plt.pie(counts,labels=counts.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ##### 74.3 % restaurants have online booking facility

# %%
sns.countplot(x=df['Has Online delivery'],hue=df['Price range'])
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='count'>

# %%
counts=df['Is delivering now'].value_counts()
plt.pie(counts,labels=counts.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ##### only 0.4% restaurants are delivering now!!

# %%
sns.countplot(x=df['Is delivering now'],hue=df['Price range'])
# Out:
# <Axes: xlabel='Is delivering now', ylabel='count'>

# %%
counts=df['Switch to order menu'].value_counts()
plt.pie(counts,labels=counts.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ##### This column seem to be useless lets remove this column.

# %%
df=df.drop(['Switch to order menu'],axis=1)

# %%
plt.figure(figsize=(10,7))
counts=df['Rating text'].value_counts()
plt.pie(counts,labels=counts.index,autopct="%1.1f%%")
plt.show()

# %%
sns.countplot(x=df['Rating text'],hue=df['Price range'])
# Out:
# <Axes: xlabel='Rating text', ylabel='count'>

# %% [markdown]
# ##### Price range 3 having more in Excellent rating.

# %% [markdown]
# ## Encoding Categorical Data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in Category:
    df[i]=le.fit_transform(df[i])
df.head()
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3743           162    73     8677       171
# 1        6304287             3168           162    73     6047       592
# 2        6300002             2893           162    75     4676       308
# 3        6318506             4700           162    75     8682       860
# 4        6314302             5515           162    75     8681       860
#
#    Locality Verbose  Cuisines  Average Cost for two  Currency  \
# 0               172       920                  1100         0
# 1               600      1111                  1200         0
# 2               314      1671                  4000         0
# 3               873      1126                  1500         0
# 4               873      1122                  1500         0
#
#    Has Table booking Has Online delivery  Is delivering now  Price range  \
# 0                  1                  No                  0            3
# ...

# %% [markdown]
# ## Lets check for outliers and remove them !

# %%
plt.figure(figsize=(15,22))
plotnumber=1
for i in Numerical:
    if plotnumber<=6:
        plt.subplot(3,3,plotnumber)
        sns.boxplot(x=df[i])
    plotnumber+=1
plt.show()

# %% [markdown]
# ## Outlier removal using Zscore method

# %%
from scipy.stats import zscore
z=np.abs(zscore(df[Numerical]))
df1=df[(z<3).all(axis=1)]
print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (9542, 19)
# Shape of the dataframe after removing outliers:  (8692, 19)
# Percentage of data loss post outlier removal:  8.907985747222805

# %% [markdown]
# ## Skewness

# %%
plt.figure(figsize=(20,30))
plotnumber=1
for i in Numerical:
    if plotnumber<=6:
        plt.subplot(3,2,plotnumber)
        sns.distplot(df[i])
    plotnumber+=1
plt.show()

# %%
df[Numerical].skew()
# Out:
# Restaurant ID           0.117696
# Country Code            8.892253
# Average Cost for two    3.709636
# Price range             1.013469
# Aggregate rating       -0.882750
# Votes                   3.642933
# dtype: float64

# %%
import pandas as pd
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson')
columns_to_transform = ['Restaurant ID', 'Country Code', 'Average Cost for two', 'Price range', 'Votes', 'Aggregate rating']
df[columns_to_transform] = pt.fit_transform(df[columns_to_transform])
skewness_after = df[columns_to_transform].skew()
print("Skewness after transformation:")
print(skewness_after)
# Out:
# Skewness after transformation:
# Restaurant ID          -0.293003
# Country Code            6.540985
# Average Cost for two    0.057037
# Price range             0.231523
# Votes                  -0.009988
# Aggregate rating       -0.623898
# dtype: float64

# %% [markdown]
# ## Correlation

# %%
df[Numerical].corr()
# Out:
#                       Restaurant ID  Country Code  Average Cost for two  \
# Restaurant ID              1.000000      0.098286             -0.160235
# Country Code               0.098286      1.000000             -0.239538
# Average Cost for two      -0.160235     -0.239538              1.000000
# Price range               -0.114487      0.196314              0.744877
# Aggregate rating          -0.297451      0.166209              0.356967
# Votes                     -0.438556      0.080960              0.469883
#
#                       Price range  Aggregate rating     Votes
# Restaurant ID           -0.114487         -0.297451 -0.438556
# Country Code             0.196314          0.166209  0.080960
# Average Cost for two     0.744877          0.356967  0.469883
# Price range              1.000000          0.438824  0.520236
# Aggregate rating         0.438824          1.000000  0.852108
# Votes                    0.520236          0.852108  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df[Numerical].corr(), annot=True,  cmap="gist_stern")
plt.show()

# %% [markdown]
# ## Lets prepare our data

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
df['Has Online delivery'] = df['Has Online delivery'].map({'Yes': 1, 'No': 0})

# %%
features = df.drop(columns=['Average Cost for two', 'Price range'])
target = df[['Average Cost for two', 'Price range']]
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train Models

# %%
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (6953, 17)
# Training target vector size: (6953, 2)
# Test feature matrix size: (1739, 17)
# Test target vector size: (1739, 2)

# %%
df = df.dropna(subset=['Average Cost for two', 'Price range'])

# %%
rf_model_avg_cost = RandomForestRegressor(random_state=42)
rf_model_price_range = RandomForestRegressor(random_state=42)

rf_model_avg_cost.fit(X_train, y_train['Average Cost for two'])
rf_model_price_range.fit(X_train, y_train['Price range'])
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_avg_cost = rf_model_avg_cost.predict(X_test)
y_pred_price_range = rf_model_price_range.predict(X_test)

# %%
# Average cost for two
mse_avg_cost = mean_squared_error(y_test['Average Cost for two'], y_pred_avg_cost)
r2_avg_cost = r2_score(y_test['Average Cost for two'], y_pred_avg_cost)

# %%
#Price Range
mse_price_range = mean_squared_error(y_test['Price range'], y_pred_price_range)
r2_price_range = r2_score(y_test['Price range'], y_pred_price_range)

# %%
print("Average Cost for Two Model:")
print(f"Mean Squared Error: {mse_avg_cost:.2f}")
print(f"R^2 Score: {r2_avg_cost:.2f}")

print("\nPrice Range Model:")
print(f"Mean Squared Error: {mse_price_range:.2f}")
print(f"R^2 Score: {r2_price_range:.2f}")
# Out:
# Average Cost for Two Model:
# Mean Squared Error: 0.32
# R^2 Score: 0.69
#
# Price Range Model:
# Mean Squared Error: 0.43
# R^2 Score: 0.56

# %%
from sklearn.linear_model import LinearRegression
lr_model_avg_cost = LinearRegression()
lr_model_avg_cost.fit(X_train, y_train['Average Cost for two'])
y_pred_avg_cost_lr = lr_model_avg_cost.predict(X_test)

mse_avg_cost_lr = mean_squared_error(y_test['Average Cost for two'], y_pred_avg_cost_lr)
r2_avg_cost_lr = r2_score(y_test['Average Cost for two'], y_pred_avg_cost_lr)

print("Linear Regression Model for Average Cost for Two:")
print(f"Mean Squared Error: {mse_avg_cost_lr:.2f}")
print(f"R^2 Score: {r2_avg_cost_lr:.2f}")
# Out:
# Linear Regression Model for Average Cost for Two:
# Mean Squared Error: 0.47
# R^2 Score: 0.54

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer, mean_squared_error

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
rf_model_avg_cost = RandomForestRegressor(random_state=42)
rf_model_price_range = RandomForestRegressor(random_state=42)
lr_model_avg_cost = LinearRegression()
lr_model_price_range = LinearRegression()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

rf_cv_avg_cost = cross_val_score(rf_model_avg_cost, features, target['Average Cost for two'], cv=kf, scoring='neg_mean_squared_error')
rf_cv_avg_cost = -rf_cv_avg_cost 
rf_cv_price_range = cross_val_score(rf_model_price_range, features, target['Price range'], cv=kf, scoring='neg_mean_squared_error')
rf_cv_price_range = -rf_cv_price_range  

print(f"RandomForestRegressor CV Results for Average Cost for Two:")
print(f"Mean MSE: {np.mean(rf_cv_avg_cost):.2f}, Std MSE: {np.std(rf_cv_avg_cost):.2f}")

print(f"RandomForestRegressor CV Results for Price Range:")
print(f"Mean MSE: {np.mean(rf_cv_price_range):.2f}, Std MSE: {np.std(rf_cv_price_range):.2f}")
# Out:
# RandomForestRegressor CV Results for Average Cost for Two:
# Mean MSE: 0.33, Std MSE: 0.02
# RandomForestRegressor CV Results for Price Range:
# Mean MSE: 0.42, Std MSE: 0.01

# %%
lr_cv_avg_cost = cross_val_score(lr_model_avg_cost, features, target['Average Cost for two'], cv=kf, scoring='neg_mean_squared_error')
lr_cv_avg_cost = -lr_cv_avg_cost

lr_cv_price_range = cross_val_score(lr_model_price_range, features, target['Price range'], cv=kf, scoring='neg_mean_squared_error')
lr_cv_price_range = -lr_cv_price_range  

print(f"LinearRegression CV Results for Average Cost for Two:")
print(f"Mean MSE: {np.mean(lr_cv_avg_cost):.2f}, Std MSE: {np.std(lr_cv_avg_cost):.2f}")

print(f"LinearRegression CV Results for Price Range:")
print(f"Mean MSE: {np.mean(lr_cv_price_range):.2f}, Std MSE: {np.std(lr_cv_price_range):.2f}")
# Out:
# LinearRegression CV Results for Average Cost for Two:
# Mean MSE: 0.49, Std MSE: 0.02
# LinearRegression CV Results for Price Range:
# Mean MSE: 0.57, Std MSE: 0.01

# %% [markdown]
# ## Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_rf = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# For Ridge Regression
param_grid_ridge = {
    'alpha': [0.1, 1, 10]
}

# %%
rf_model = RandomForestRegressor(random_state=42)
grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid_rf, 
                               scoring='neg_mean_squared_error', cv=5, n_jobs=-1, verbose=2)


grid_search_rf.fit(features, target['Average Cost for two'])
best_rf_params = grid_search_rf.best_params_
best_rf_score = -grid_search_rf.best_score_

print(f"Best Parameters for RandomForestRegressor: {best_rf_params}")
print(f"Best Score (MSE) for RandomForestRegressor: {best_rf_score:.2f}")
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters for RandomForestRegressor: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Best Score (MSE) for RandomForestRegressor: 0.44

# %% [markdown]
# ## Final Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge

final_rf_model = RandomForestRegressor(n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, random_state=42)
final_ridge_model = Ridge(alpha=1)

final_rf_model.fit(X_train, y_train['Average Cost for two'])
final_ridge_model.fit(X_train, y_train['Average Cost for two'])
# Out:
# Ridge(alpha=1)

# %%
y_pred_rf = final_rf_model.predict(X_test)
y_pred_ridge = final_ridge_model.predict(X_test)

# %% [markdown]
# ## Save Model

# %%
import joblib
joblib.dump(final_rf_model, 'final_rf_model.pkl')
joblib.dump(final_ridge_model, 'final_ridge_model.pkl')
# Out:
# ['final_ridge_model.pkl']
