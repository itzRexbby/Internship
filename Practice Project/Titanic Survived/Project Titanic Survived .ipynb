# %% [markdown]
# # Titanic survived Project
#
# ### Project Description
#
# The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. It gives you information about multiple people like their ages, sexes, sibling counts, embarkment points, and whether or not they survived the disaster.
# Based on these features, you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.
#
# #### Attribute Information
#
# Passenger id- Unique Id of the passenger
#
# Pclass- Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
#
# Survived- Survived (0 = No; 1 = Yes)
#
# Name- Name of the passenger
#
# Sex- Sex of the passenger (Male, Female)
#
# Age- Age of the passenger
#
# Sibsp- Number of Siblings/Spouses Aboard
#
# Parch- Number of Parents/Children Aboard
#
# Ticket- Ticket Number
#
# Fare- Passenger Fare (British pound)
#
# Cabin- Cabin
#
# Embarked- Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
#
# Dataset Link-
# https://github.com/FlipRoboTechnologies/ML-Datasets/blob/main/Titanic/titanic_train.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Titanic/titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print('No. of Rows :',df.shape[0])
print('No. of Columns :',df.shape[1])
pd.set_option('display.max_columns',None)
df.head()
# Out:
# No. of Rows : 891
# No. of Columns : 12
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']}

# %% [markdown]
# #### Observation :
# - **This Titanic Dataset contains 891 rows & 12 columns.**
# - **Here our objective is to predict survival using classification algorithim for that Here our target variable is 'Survived'.**
# - **We have 5 features with object datatypes & rest are with numerical features.**

# %% [markdown]
# # Data Integrity Check
# - **Dataset can contain whitespaces, missing value, duplicates entries, let investigate integrity of data before proceeding for further analysis.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate entry present in the dataframe

# %%
df.isin([' ','?','-','null','NA']).sum().any()
# Out:
# False

# %% [markdown]
# No Null value present

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.isnull(),cmap = 'cool_r')
plt.show()

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#              Missing Values  % Missing data
# Cabin                   687       77.104377
# Age                     177       19.865320
# Embarked                  2        0.224467
# PassengerId               0        0.000000
# Survived                  0        0.000000
# Pclass                    0        0.000000
# Name                      0        0.000000
# Sex                       0        0.000000
# SibSp                     0        0.000000
# Parch                     0        0.000000
# Ticket                    0        0.000000
# Fare                      0        0.000000

# %% [markdown]
# ### Observation :
# - **Dataset do not contain any duplicate values, whitespaces,"?","-" .**
# - **Feature'Age', 'Embarked', and 'Cabin' have null values.**
# - **19.86% of 'Age' data is null value,0.22% of 'Embarked' is null value, while 77.10% 'Cabin' data is null value.**
# - **Dropping 'Cabin' since 77.10% of its values is missing and therefore it cannot contribute to building a good model for predicting the target variable values.**

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include= object)
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# - **"Survived" - Target / Label column has 2 categories / classes.**
#
# - **"sex" - Feature column has 2 categories / classes.**
#
# - **"Pclass" - Feature column has 2 categories / classes.**
#
# - **"Embarked" -  Feature column has 3 categories / classes.**
#
# - **"SibSp" -  Feature column has 7 discrete values.**
#
# - **"Parch" - Feature column has 7 discrete values.**

# %%
df.drop(columns=['Cabin'],inplace = True)

# %% [markdown]
# ## How Many Survived?

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(5,3)) 
sns.countplot(data=df, x='Survived')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Count of Survived')
plt.show()

# %% [markdown]
# ##### Survived
# - 0 means Not Survived
# - 1 means Survived

# %%
gg=df.groupby(['Sex','Survived'])['Survived'].count()

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Count of Survived by Sex')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ##### As we can see above the number of male is lot mroe than female still more than 2x female were saved. The survival rate for females around 75% while the male having 18-19%.
# ### Survival Rate : Female (75%) > Male (18-19%)

# %%
pd.crosstab(df.Pclass,df.Survived,margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.title('Count of Survived by Pclass')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ##### We can clearly, see that Passengers of Pclass 1 were given a very high priority while rescue. Even though the the number of passengers in Pclass 3 were a lot higher, still the number of survival from Pclass 3 is very low, somewhere around 25%.
# ##### For Pclass 1 % Survived is around 63% while for pclass2 is around 48%. In Conclusion money and status matters. Such a materialistic world.

# %% [markdown]
# # Age

# %%
print('Oldest Passenger was of:',df['Age'].max(),'Years')
print('Youngest Passenger was of:',df['Age'].min(),'Years')
print('Average Age on th ship :',df['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on th ship : 29.69911764705882 Years

# %%
sns.violinplot(data=df, x='Sex', y='Age', hue='Survived', split=True)
plt.xlabel('Sex')
plt.ylabel('Age')
plt.title('Age Distribution by Sex and Survival Status')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Handle the NaN entries in Age column

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Initial']=0
for i in df:
    df['Initial']=df.Name.str.extract("([A-Za-z]+)\.")

# %%
pd.crosstab(df.Initial,df.Sex)
# Out:
# Sex       female  male
# Initial
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
df['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                      ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
df.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
mean_age = df['Age'].mean()

# %%
df['Age'].fillna(mean_age, inplace=True)

# %%
df.loc[(df.Age.isnull() & (df.Initial)=='Mr'), 'Age'].fillna(32.73,inplace = True)

# %%
df.loc[(df['Age'].isnull()) & (df['Initial'] == 'Mr'), 'Age'] = 32.73
df.loc[(df['Age'].isnull()) & (df['Initial'] == 'Mrs'), 'Age'] = 35.98
df.loc[(df['Age'].isnull()) & (df['Initial'] == 'Master'), 'Age'] = 4.57
df.loc[(df['Age'].isnull()) & (df['Initial'] == 'Miss'), 'Age'] = 21.86
df.loc[(df['Age'].isnull()) & (df['Initial'] == 'Other'), 'Age'] = 45.889

# %% [markdown]
# ##### We filled the mean values according to their initials like we consider women and men having different ages .

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
df.groupby(['Age','Survived'])['Survived'].count()
# Out:
# Age    Survived
# 0.42   1           1
# 0.67   1           1
# 0.75   1           2
# 0.83   1           2
# 0.92   1           1
#                   ..
# 70.00  0           2
# 70.50  0           1
# 71.00  0           2
# 74.00  0           1
# 80.00  1           1
# Name: Survived, Length: 144, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))
df[df['Survived'] == 0]['Age'].plot.hist(ax=ax[0], bins=20, edgecolor='black', color='red')
ax[0].set_title('Survived = 0', fontsize=20, fontweight='bold')
ax[0].set_xticks(range(0, 85, 5))
df[df['Survived'] == 1]['Age'].plot.hist(ax=ax[1], bins=20, edgecolor='black', color='green')
ax[1].set_title('Survived = 1', fontsize=20, fontweight='bold')
ax[1].set_xticks(range(0, 85, 5))
plt.show()

# %% [markdown]
# ### Observation :-
# - The Toddlers(age<5) were saved in large numbers. Possibliy, Women and Child first policy employs while rescue operation employed.
# - The oldest Passenger was saved (80 years).
# - Maximum number of deaths were in age group of 30-40.

# %% [markdown]
# ### Analysis Embarked vs Survival

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_085ef_row0_col0, #T_085ef_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_085ef_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_085ef_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_085ef_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_085ef_row0_col4, #T_085ef_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_085ef_row1_col0, #T_085ef_row3_col0, #T_085ef_row3_col1, #T_085ef_row3_col2, #T_085ef_row3_col3, #T_085ef_row3_col4, #T_085ef_row4_col0, #T_085ef_row4_col2, #T_085ef_row4_col3, #T_085ef_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_085ef_row1_col1, #T_085ef_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_085ef_row1_col3, #T_085ef_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_085ef_row2_col0, #T_085ef_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_085ef_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_085ef_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_085ef_row2_col4, #T_085ef_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_085ef_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_085ef_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_085ef_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_085ef_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_085ef_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_085ef_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_085ef_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_085ef_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_085ef_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_085ef_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_085ef_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_085ef_row7_col3, #T_085ef_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_085ef_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_085ef_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_085ef_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_085ef_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_085ef_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_085ef_row9_col0, #T_085ef_row9_col1, #T_085ef_row9_col2, #T_085ef_row9_col3, #T_085ef_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_085ef">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_085ef_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_085ef_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_085ef_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_085ef_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_085ef_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_085ef_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_085ef_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_085ef_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_085ef_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_085ef_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_085ef_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_085ef_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_085ef_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_085ef_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_085ef_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_085ef_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_085ef_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_085ef_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_085ef_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_085ef_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_085ef_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_085ef_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_085ef_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_085ef_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_085ef_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_085ef_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_085ef_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_085ef_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_085ef_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_085ef_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_085ef_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_085ef_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_085ef_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_085ef_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_085ef_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_085ef_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_085ef_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_085ef_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_085ef_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_085ef_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_085ef_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_085ef_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_085ef_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_085ef_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_085ef_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_085ef_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_085ef_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_085ef_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_085ef_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_085ef_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_085ef_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_085ef_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_085ef_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_085ef_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_085ef_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_085ef_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_085ef_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_085ef_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_085ef_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_085ef_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
sns.countplot(x='Embarked',hue='Survived',data=df)
fig=plt.gcf()
fig.set_size_inches(6,4)
plt.show()

# %% [markdown]
# ##### Maximum passengers boarded from S. Passengers from C look to be lucky as good proportion of them survived.

# %% [markdown]
# ### Filling Embarked NaN

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# # SibSip vs Survived

# %%
pd.crosstab([df.SibSp],[df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8e447_row0_col0 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_8e447_row0_col1 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_8e447_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_8e447_row1_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_8e447_row1_col1 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_8e447_row1_col2 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_8e447_row2_col0, #T_8e447_row4_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_8e447_row2_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_8e447_row2_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_8e447_row3_col0, #T_8e447_row3_col2, #T_8e447_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_8e447_row3_col1, #T_8e447_row4_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_8e447_row5_col0, #T_8e447_row5_col1, #T_8e447_row5_col2, #T_8e447_row6_col0, #T_8e447_row6_col1, #T_8e447_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_8e447_row7_col0, #T_8e447_row7_col1, #T_8e447_row7_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e447">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_8e447_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8e447_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8e447_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e447_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e447_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_8e447_row0_col1" class="data row0 col1" >210</td>
#       <td id="T_8e447_row0_col2" class="data row0 col2" >608</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e447_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_8e447_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_8e447_row1_col2" class="data row1 col2" >209</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e447_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_8e447_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_8e447_row2_col2" class="data row2 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e447_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_8e447_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_8e447_row3_col2" class="data row3 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e447_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_8e447_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_8e447_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8e447_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_8e447_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_8e447_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_8e447_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_8e447_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_8e447_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8e447_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_8e447_row7_col0" class="data row7 col0" >549</td>
#       <td id="T_8e447_row7_col1" class="data row7 col1" >342</td>
#       <td id="T_8e447_row7_col2" class="data row7 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.countplot(x='SibSp',hue='Survived',data=df)
fig=plt.gcf()
fig.set_size_inches(6,4)
plt.show()

# %% [markdown]
# ##### Passenger have 34.5% survival rate. The graph roughly decreases if the number of sibilings increase.
# ##### The crosstab shows that person with SibSp>3 were all in Pclass. It is imminent that all the large families in Pclass 3 (>3) died.

# %% [markdown]
# ## Parch Vs Survial

# %%
pd.crosstab([df.Parch],[df.Pclass],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c6e50_row0_col0 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_c6e50_row0_col1 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_c6e50_row0_col2 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_c6e50_row0_col3 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_c6e50_row1_col0 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_c6e50_row1_col1 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_c6e50_row1_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_c6e50_row1_col3 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_c6e50_row2_col0 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_c6e50_row2_col1, #T_c6e50_row2_col3 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_c6e50_row2_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_c6e50_row3_col0, #T_c6e50_row4_col1, #T_c6e50_row4_col3, #T_c6e50_row5_col0, #T_c6e50_row5_col1, #T_c6e50_row6_col0, #T_c6e50_row6_col1, #T_c6e50_row6_col2, #T_c6e50_row6_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c6e50_row3_col1, #T_c6e50_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_c6e50_row3_col2, #T_c6e50_row3_col3, #T_c6e50_row4_col0, #T_c6e50_row4_col2, #T_c6e50_row5_col3 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_c6e50_row7_col0, #T_c6e50_row7_col1, #T_c6e50_row7_col2, #T_c6e50_row7_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6e50">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_c6e50_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_c6e50_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_c6e50_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_c6e50_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6e50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6e50_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_c6e50_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_c6e50_row0_col2" class="data row0 col2" >381</td>
#       <td id="T_c6e50_row0_col3" class="data row0 col3" >678</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6e50_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_c6e50_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_c6e50_row1_col2" class="data row1 col2" >55</td>
#       <td id="T_c6e50_row1_col3" class="data row1 col3" >118</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6e50_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_c6e50_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_c6e50_row2_col2" class="data row2 col2" >43</td>
#       <td id="T_c6e50_row2_col3" class="data row2 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6e50_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c6e50_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_c6e50_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_c6e50_row3_col3" class="data row3 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c6e50_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_c6e50_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c6e50_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_c6e50_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c6e50_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c6e50_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c6e50_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_c6e50_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c6e50_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_c6e50_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c6e50_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_c6e50_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c6e50_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_c6e50_row7_col0" class="data row7 col0" >216</td>
#       <td id="T_c6e50_row7_col1" class="data row7 col1" >184</td>
#       <td id="T_c6e50_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_c6e50_row7_col3" class="data row7 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot(x='SibSp',y='Survived',data=df)
fig=plt.gcf()
fig.set_size_inches(6,4)
plt.show()

# %% [markdown]
#  - Here too the results are quite similar. Passengers with their parents onboard have greater chance of survival. it however reduces as the number goes up.
#  - The chances of survival is good for somebody who has 1-3 parents on the ship

# %% [markdown]
# ## Fare Vs Survival

# %%
print('Highest Fare was :',df['Fare'].max())
print('Highest Fare was :',df['Fare'].min())
print('Average Fare was :',df['Fare'].mean())
# Out:
# Highest Fare was : 512.3292
# Highest Fare was : 0.0
# Average Fare was : 32.204207968574636

# %%
f,ax=plt.subplots(1,3,figsize=(20,7))
sns.distplot(df[df['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1',fontsize= 20, fontweight='bold')
ax[0].set_ylabel('Density',fontsize= 18, fontweight='bold')
ax[0].set_xlabel('Fares', fontsize= 18, fontweight='bold')

sns.distplot(df[df['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2',fontsize= 20, fontweight='bold')
ax[1].set_ylabel('Density',fontsize= 18, fontweight='bold')
ax[1].set_xlabel('Fares', fontsize= 18, fontweight='bold')

sns.distplot(df[df['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3',fontsize= 20, fontweight='bold')
ax[2].set_ylabel('Density',fontsize= 18, fontweight='bold')
ax[2].set_xlabel('Fares', fontsize= 18, fontweight='bold')
plt.show()

# %% [markdown]
# - There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also Continous , we can convert into discrete values by using binning

# %%
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(data=df, hue='Pclass')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.corr(), annot= True)
plt.show()

# %%
plt.figure(figsize = (12,5))
df.corr()['Survived'].drop(['Survived']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Survived',fontsize=15)
plt.title('Correlation of Survived with Features',fontsize = 18)
plt.show()

# %% [markdown]
# # Outliers Detection and Removal

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Name', 'Sex', 'Ticket', 'Embarked', 'Initial']}

# %%
df.drop(["PassengerId", "Name" , "Ticket" ],axis=1,inplace=True)

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Sex', 'Embarked', 'Initial']}

# %%
Numerical_features= ['Survived', 'Pclass', 'SibSp', 'Parch','Age', 'Fare']
Categorical_features = ['Sex', 'Embarked', 'Initial']

# %%
plt.figure(figsize=(12,10))
plotnumber=1
for i in Numerical_features:
    if plotnumber<=10:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# - We can see that continous features like age & fare contains outliers.

# %%
df2=df.copy()
Q1 =df2.quantile(0.25)
Q3= df2.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# Survived     1.0000
# Pclass       1.0000
# Age         13.0000
# SibSp        1.0000
# Parch        0.0000
# Fare        23.0896
# dtype: float64

# %%
df_new =df2[~((df <(Q1 - 1.5*IQR)) | (df >(Q3 + 1.5*IQR))).any(axis=1)]
print(df_new.shape)
# Out:
# (577, 9)

# %%
df.shape
# Out:
# (891, 9)

# %%
percentage_removed = ((df.shape[0] - df_new.shape[0]) / df_new.shape[0]) * 100
print("Loss percentage : ",percentage_removed,'%')
# Out:
# Loss percentage :  54.41941074523397 %

# %% [markdown]
# # Coverted the categorical features into string then go for Standard Scaler

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical_features:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Initial
# 0         0       3    1  22.0      1      0   7.2500         2        2
# 1         1       1    0  38.0      1      0  71.2833         0        3
# 2         1       3    0  26.0      0      0   7.9250         2        1
# 3         1       1    0  35.0      1      0  53.1000         2        3
# 4         0       3    1  35.0      0      0   8.0500         2        2

# %%
# Splitting data in target and dependent feature
X = df.drop(['Survived'], axis =1)
Y = df['Survived']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Machine Learning Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=67, test_size=.25)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (668, 8)
# Training target vector size: (668,)
# Test feature matrix size: (223, 8)
# Test target vector size: (223,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(50,300):
    X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8507462686567164 on Random_state 76

# %%
####### LOGISTIC REGRESSION #######

X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=69, test_size=.25)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8251121076233184
#
#
# Confusion matrix of Logistics Regression :
#  [[123  17]
#  [ 22  61]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       140
#            1       0.78      0.73      0.76        83
#
#     accuracy                           0.83       223
#    macro avg       0.82      0.81      0.81       223
# weighted avg       0.82      0.83      0.82       223

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(log_reg, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', log_reg, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score LogisticRegression() :
#
# CVScore : [0.77094972 0.78089888 0.78089888 0.78089888 0.83146067]
# Mean CV Score : 0.7890214048082355
# Std deviation : 0.02156665831077915

# %% [markdown]
# ### **Decision Tree Classifier**

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
y_pred=dtc.predict(X_test)
print('\033[1m'+'Decision Tree Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Decision Tree Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Decision Tree Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Decision Tree Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Decision Tree Classifier Evaluation
#
#
# Accuracy Score of Decision Tree Classifier : 0.7847533632286996
#
#
# Confusion matrix of Decision Tree Classifier :
#  [[117  23]
#  [ 25  58]]
#
#
# classification Report of Decision Tree Classifier
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       140
#            1       0.72      0.70      0.71        83
#
#     accuracy                           0.78       223
#    macro avg       0.77      0.77      0.77       223
# weighted avg       0.78      0.78      0.78       223

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(dtc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', dtc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score DecisionTreeClassifier() :
#
# CVScore : [0.73184358 0.74719101 0.84831461 0.74157303 0.79213483]
# Mean CV Score : 0.7722114117130123
# Std deviation : 0.043319584028187315

# %% [markdown]
# ### **Random Forest Classifier**

# %%
rfc=RandomForestClassifier()
rfc.fit(X_train,Y_train)
y_pred=rfc.predict(X_test)
print('\033[1m'+'Random Forest Classifier'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Random Forest Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Random Forest Classifier
#
#
# Accuracy Score of Random Forest Classifier : 0.8071748878923767
#
#
# Confusion matrix of Random Forest Classifier :
#  [[121  19]
#  [ 24  59]]
#
#
# classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       140
#            1       0.76      0.71      0.73        83
#
#     accuracy                           0.81       223
#    macro avg       0.80      0.79      0.79       223
# weighted avg       0.81      0.81      0.81       223

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(rfc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', rfc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score RandomForestClassifier() :
#
# CVScore : [0.79888268 0.81460674 0.86516854 0.75842697 0.8258427 ]
# Mean CV Score : 0.8125855250768941
# Std deviation : 0.03483024177685645

# %% [markdown]
# ### **AdaBoost Classifier**

# %%
adbc=AdaBoostClassifier()
adbc.fit(X_train,Y_train)
y_pred=adbc.predict(X_test)
print('\033[1m'+'AdaBoost Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of AdaBoost Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of AdaBoost Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of AdaBoost Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# AdaBoost Classifier Evaluation
#
#
# Accuracy Score of AdaBoost Classifier : 0.8430493273542601
#
#
# Confusion matrix of AdaBoost Classifier :
#  [[122  18]
#  [ 17  66]]
#
#
# classification Report of AdaBoost Classifier
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       140
#            1       0.79      0.80      0.79        83
#
#     accuracy                           0.84       223
#    macro avg       0.83      0.83      0.83       223
# weighted avg       0.84      0.84      0.84       223

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(adbc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score',adbc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score AdaBoostClassifier() :
#
# CVScore : [0.77653631 0.80898876 0.8258427  0.81460674 0.86516854]
# Mean CV Score : 0.8182286108844391
# Std deviation : 0.028628907091265175

# %% [markdown]
# ### **Gradient Boosting Classifier*

# %%
grad_bc=GradientBoostingClassifier()
grad_bc.fit(X_train,Y_train)
y_pred=grad_bc.predict(X_test)
print('\033[1m'+'Gradient Boosting Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Gradient Boosting Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Gradient Boosting Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Gradient Boosting Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Gradient Boosting Classifier Evaluation
#
#
# Accuracy Score of Gradient Boosting Classifier : 0.8430493273542601
#
#
# Confusion matrix of Gradient Boosting Classifier :
#  [[129  11]
#  [ 24  59]]
#
#
# classification Report of Gradient Boosting Classifier
#                precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       140
#            1       0.84      0.71      0.77        83
#
#     accuracy                           0.84       223
#    macro avg       0.84      0.82      0.83       223
# weighted avg       0.84      0.84      0.84       223

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(grad_bc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', grad_bc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score GradientBoostingClassifier() :
#
# CVScore : [0.82122905 0.8258427  0.85393258 0.79213483 0.86516854]
# Mean CV Score : 0.8316615403929445
# Std deviation : 0.025782842684939754

# %% [markdown]
# ## **Hyper Parameter Tuning : GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = [{'fit_intercept': [True, False], #default: True
            'penalty': ['l1','l2'],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], #default: lbfgs
            'random_state': [69]
             }]

# %%
GCV = GridSearchCV(LogisticRegression(),parameter,verbose=5)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.813 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.761 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.821 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.752 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.805 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.821 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.769 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.752 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.805 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.821 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.752 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.769 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.805 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.821 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.769 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.752 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.805 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.784 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.821 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.752 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.805 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.759 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.789 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.759 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.789 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.767 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.767 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.797 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.767 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.767 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.797 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.769 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.784 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.806 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.767 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.797 total time=   0.0s
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'fit_intercept': [True, False],
#                           'penalty': ['l1', 'l2'], 'random_state': [69],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=5)

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True, 'penalty': 'l1', 'random_state': 69, 'solver': 'saga'}

# %% [markdown]
# ### Final Model

# %%
Final_mod = LogisticRegression(fit_intercept =True,penalty= "l2",solver='newton-cg',random_state= 69)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Final Random Forest Classifier Model'+'\033[0m')
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'Classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Final Random Forest Classifier Model
# Accuracy Score :
#  0.8251121076233184
#
#
# Confusion matrix of Random Forest Classifier :
#  [[123  17]
#  [ 22  61]]
#
#
# Classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       140
#            1       0.78      0.73      0.76        83
#
#     accuracy                           0.83       223
#    macro avg       0.82      0.81      0.81       223
# weighted avg       0.82      0.83      0.82       223

# %%
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
y_prob = Final_mod.predict_proba(X_test)[:, 1]

auc_score = roc_auc_score(Y_test, y_prob)

print('\033[1m' + 'AUC Score :' + '\033[0m\n', auc_score)
# Out:
# AUC Score :
#  0.8720740103270223

# %% [markdown]
# ## Predicting the Final Model

# %%
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 1              0
# 1                 0              0
# 2                 1              1
# 3                 0              0
# 4                 0              0
